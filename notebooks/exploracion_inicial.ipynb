# %% [markdown]
# ### Analisis Exploratorio de datos Visualizacion - Predicción de las carreras stem

# %% [markdown]
# Este notebook documenta el analis de los resultados mostrados por los graficos creados para tomar en cuenta información relevante que influye a los estudiantes a optar por carreras STEM.

# %% [markdown]
# Importación de librerias
#
# En la siguiente línea se importan todos los métodos de los gráficos de la clase Visualizador desde el archivo de código del paquete visualización. También se importan las librerias pandas, seaborn y matplolib.

# %%
from visualizacion.visualizador import *
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import plotly.express as px
import numpy as np

# %% [markdown]
# #### Ejecución de los gráficos y analisis de los resultados

# %% [markdown]
# ### Gráficos de líneas

# %%
#Gráfico de lineas de la evolucion de las carreras stem
print("Mostrando: Evolución de las carreras STEM")
    fig_evolucion = viz.lineal_evolucion()
    plt.show()

# %% [markdown]
# En este gráfico se muestra la evolución del numero de estudiantes STEM entre el 2019 al 2022 diferenciados por zona de urbanización. Se puede apreciar que todas las zonas hay un crecimiento leve en la cantidad de estudiantes a lo largo del tiempo, sin embargo la categoria predominante urbano tiene la mayor cantidad de estudiantes en toda la línea de tiempo.

# %%
#Grafico de lineas de la evolución del internet
print("Mostrando: Evolución de Internet")
    fig_internet = viz.lineal_internet()
    plt.show()

# %% [markdown]
# En este gráfico se muestra la evolución del acceso a internet en las distintas zonas de Costa Rica entre el 2019-2022. Se puede apreciar que entre las regiones central y pacifico central hay niveles más altos de acceso en cambio en la region del huetar norte hay menor cantidad de nivel de internet más bajo durante el periodo de años.

# %% [markdown]
# ### Graficos de barras

# %%
#Grafico de barras
print("Mostrando: Cantidad de estudiantes de acuerdo su tipo de sexo en carreras STEM/No STEM")
    fig_analisis_stem_nostem = viz.barras_analisis_stem_nostem()
    plt.show()

# %% [markdown]
# En este gráfico se compara la cantidad de estudiantes matriculados en áreas stem y no stem según su sexo. Se puede apreciar que los hombres que la matricula en carreras stem y carreras no stem es muy equilibrada, en cambio las mujueres tienen una diferencia alta de matriculas no stem mayor que stem.

# %%
#Grafico de barras apiladas
print("Mostrando: Porcentaje de estudiantes que eligen carreras STEM en zonas urbanas")
    fig_zona_stem = viz.barras_apiladas_zona_stem()
    plt.show()

# %% [markdown]
# En este gráfico se muestra el porcentaje de estudiantes en áreas stem y no stem segun su zona de residencia. Se puede apreciar que en zonas rurales como urbanas, la proporción de studiantes es muy similar: alrededor de 60% en no STEM y 40% en STEM. Sin embargo, no se observa una diferencia marcada entre residencias rurales y urbanas en cuanto a la elección de áreas STEM.

# %% [markdown]
# ### Histograma

# %%
#Histograma de la distribución de edades de los estudiantes
print("Mostrando: Distribución de Edades")
    fig_edad = viz.histo_distribuccion_edad()
    plt.show()

# %% [markdown]
# En este grafico se muestra la distribución de edades de los estudiantes. Se puede apreciar que la mayoría de estudiantes se ubica en edades jóvenes, lo que genera un pico muy alto al inicio del gráfico.

# %% [markdown]
# ### Mapa de calor

# %%
#Mapa de correlacion
print("Mostrando: Matriz de Correlación")
    viz_final = Visualizador(df_final)
    fig_corr = viz_final.heatmap_correlacion()
    plt.show()

# %% [markdown]
# La matriz de correlación muestra que la única relación destacable es entre el año y el acceso a Internet, con una correlación positiva de 0.30. Las demás variables presentan correlaciones muy bajas, lo que indica que no están directamente relacionadas.
